# %% [markdown]
# # Datos sintéticos
#
# Uno de los mayores problemas a la hora de emplear datos empresariales es disponer de suficientes garantías de anonimato en caso de disponer de datos personales. En líneas generales, los datos sintéticos nos permiten entrenar generadores que pueden generar conjuntos de datos que presentan las mismas estadísticas que los datos originales siendo plenamente artificiales.
#
# * Web: https://sdv.dev/
# * Documentación: https://docs.sdv.dev/sdv

# %%
# !pip install sdv

# %%
from sdv.datasets.demo import download_demo

real_data, metadata = download_demo(
    modality='single_table',
    dataset_name='fake_hotel_guests'
)
real_data.head()
# Out:
#                guest_email  has_rewards room_type  amenities_fee checkin_date  \
# 0  michaelsanders@shaw.net        False     BASIC          37.89  27 Dec 2020
# 1        randy49@brown.biz        False     BASIC          24.37  30 Dec 2020
# 2    webermelissa@neal.com         True    DELUXE           0.00  17 Sep 2020
# 3          gsims@terry.com        False     BASIC            NaN  28 Dec 2020
# 4        misty33@smith.biz        False     BASIC          16.45  05 Apr 2020
#
#   checkout_date  room_rate                                    billing_address  \
# 0   29 Dec 2020     131.23        49380 Rivers Street\nSpencerville, AK 68265
# 1   02 Jan 2021     114.43          88394 Boyle Meadows\nConleyberg, TN 22063
# 2   18 Sep 2020     368.33  0323 Lisa Station Apt. 208\nPort Thomas, LA 82585
# 3   31 Dec 2020     115.61          77 Massachusetts Ave\nCambridge, MA 02139
# 4           NaN     122.41             1234 Corporate Drive\nBoston, MA 02116
#
#     credit_card_number
# 0  4075084747483975747
# 1      180072822063468
# 2       38983476971380
# 3     4969551998845740
# 4     3558512986488983

# %%
metadata.visualize()

# %%
from sdv.single_table import CTGANSynthesizer

synthesizer = CTGANSynthesizer(metadata)

# %%
synthesizer.fit(
    data=real_data
)

# %%
synthetic_data = synthesizer.sample(
    num_rows=500
)

synthetic_data.head()
# Out:
#                     guest_email  has_rewards room_type  amenities_fee  \
# 0         dsullivan@example.net         True     BASIC          10.56
# 1          steven59@example.org        False     BASIC          10.76
# 2         brandon15@example.net        False     BASIC           0.00
# 3  humphreyjennifer@example.net        False     BASIC          19.67
# 4       joshuabrown@example.net         True    DELUXE           5.23
#
#   checkin_date checkout_date  room_rate  \
# 0  06 Oct 2020   30 Apr 2020     197.10
# 1  18 Jun 2020   06 Dec 2020     227.61
# 2  30 Jan 2020   27 Sep 2020     398.79
# 3  20 May 2020   09 Jan 2020      99.02
# 4  12 Dec 2020   24 Jul 2020     128.47
#
#                                      billing_address   credit_card_number
# 0   90469 Karla Knolls Apt. 781\nSusanberg, CA 70033     5161033759518983
# 1     6108 Carla Ports Apt. 116\nPort Evan, MI 71694  4133047413145475690
# 2  86709 Jeremy Manors Apt. 786\nPort Garychester...        4977328103788
# 3            8906 Bobby Trail\nEast Sandra, NY 43986     3524946844839485
# 4       732 Dennis Lane\nPort Nicholasstad, DE 49786  4446905799576890978

# %%
from sdv.evaluation.single_table import run_diagnostic

diagnostic = run_diagnostic(
    real_data=real_data,
    synthetic_data=synthetic_data,
    metadata=metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 9/9 [00:00<00:00, 2190.62it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 722.53it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%

# %%
from sdv.evaluation.single_table import evaluate_quality

quality_report = evaluate_quality(
    real_data,
    synthetic_data,
    metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 9/9 [00:00<00:00, 1398.10it/s]|
# Column Shapes Score: 78.5%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 36/36 [00:00<00:00, 855.75it/s]|
# Column Pair Trends Score: 76.64%
#
# Overall Score (Average): 77.57%

# %%
quality_report.get_details('Column Shapes')
# Out:
#           Column        Metric     Score
# 0    has_rewards  TVComplement  0.810000
# 1      room_type  TVComplement  0.784000
# 2  amenities_fee  KSComplement  0.662739
# 3   checkin_date  KSComplement  0.790000
# 4  checkout_date  KSComplement  0.827083
# 5      room_rate  KSComplement  0.836000

# %%
sensitive_column_names = ['guest_email', 'billing_address', 'credit_card_number']

real_data[sensitive_column_names].head(3)
# Out:
#                guest_email                                    billing_address  \
# 0  michaelsanders@shaw.net        49380 Rivers Street\nSpencerville, AK 68265
# 1        randy49@brown.biz          88394 Boyle Meadows\nConleyberg, TN 22063
# 2    webermelissa@neal.com  0323 Lisa Station Apt. 208\nPort Thomas, LA 82585
#
#     credit_card_number
# 0  4075084747483975747
# 1      180072822063468
# 2       38983476971380

# %%
synthetic_data[sensitive_column_names].head(3)
# Out:
#              guest_email                                    billing_address  \
# 0  dsullivan@example.net   90469 Karla Knolls Apt. 781\nSusanberg, CA 70033
# 1   steven59@example.org     6108 Carla Ports Apt. 116\nPort Evan, MI 71694
# 2  brandon15@example.net  86709 Jeremy Manors Apt. 786\nPort Garychester...
#
#     credit_card_number
# 0     5161033759518983
# 1  4133047413145475690
# 2        4977328103788

# %%
from sdv.evaluation.single_table import get_column_plot

fig = get_column_plot(
    real_data=real_data,
    synthetic_data=synthetic_data,
    column_name='room_rate',
    metadata=metadata
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_23.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
from sdv.evaluation.single_table import get_column_pair_plot

fig = get_column_pair_plot(
    real_data=real_data,
    synthetic_data=synthetic_data,
    column_names=['checkin_date', 'checkout_date'],
    metadata=metadata
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_24.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
synthesizer.save('modelos/my_synthesizer.pkl')

# %% [markdown]
# ### Con datos nuestros
#
# Probemos como resultaría con datos con los que hemos trabajado antes...

# %%
import pandas as pd

titanic = pd.read_csv("../assets/data/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from sdv.metadata import Metadata

metadata = Metadata.detect_from_dataframe(
    data=titanic,
    table_name='titanic')

metadata.visualize()

# %%
from sdv.single_table import GaussianCopulaSynthesizer

synthesizer = GaussianCopulaSynthesizer(metadata)
synthesizer.fit(titanic)

# %%
fake_titanic = synthesizer.sample(num_rows=100)
fake_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0      4326007         0       1
# 1      4069891         0       3
# 2      2697777         0       2
# 3     10119885         1       3
# 4      4368626         0       1
#
#                                               Name     Sex    Age  SibSp  \
# 0  Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)  female  39.11      0
# 1                               Niskanen, Mr. Juha    male  29.45      0
# 2                              Betros, Mr. Tannous    male  38.61      1
# 3                      Parkes, Mr. Francis "Frank"    male  28.06      0
# 4                          Oreskovic, Miss. Marija    male    NaN      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 0      0      2626  73.2513   D37        S
# 1      0  A/5 2817   4.6504   NaN        S
# 2      0    113806   6.7210   NaN        S
# 3      2    347082  27.8694   NaN        C
# 4      0    230136  10.5493   NaN        S

# %%
from sdv.single_table import TVAESynthesizer

synthesizer = TVAESynthesizer(metadata)
synthesizer.fit(titanic)

synthesizer.sample(num_rows=10)
# Out:
#    PassengerId  Survived  Pclass                                        Name  \
# 0      4326007         0       3                         Haas, Miss. Aloisia
# 1      4069891         0       3  Strom, Mrs. Wilhelm (Elna Matilda Persson)
# 2      2697777         0       3                          Markoff, Mr. Marin
# 3     10119885         0       3                     Masselmani, Mrs. Fatima
# 4      4368626         1       3                          Skoog, Mr. Wilhelm
# 5     11641463         0       3                           Lester, Mr. James
# 6      7214272         0       3                          Maisner, Mr. Simon
# 7      9787275         1       3       Baclini, Mrs. Solomon (Latifa Qurban)
# 8      4599517         0       3                          Henry, Miss. Delia
# 9      1953199         0       3                           Smith, Mr. Thomas
#
#       Sex    Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  28.95      0      0  W/C 14208   9.3566   NaN        S
# 1  female  21.65      1      1     382652  14.0295   NaN        S
# 2    male  29.36      0      0     349213   6.4788   NaN        S
# 3    male  29.05      0      0      54636   7.5446   NaN        S
# 4  female    NaN      1      0  A/5. 3336  29.0745   NaN        S
# 5    male    NaN      0      0  A/4 48871   8.6512   NaN        S
# 6    male  28.80      0      0     350042   7.6396   NaN        S
# 7  female  29.62      1      0       2661  23.1181   NaN        S
# 8    male  30.23      0      0     382649   7.0861   NaN        S
# 9    male  29.62      0      0     370377   6.4587   NaN        S

# %%
from sdv.sampling import Condition

low_class_male = Condition(
    num_rows=10,
    column_values={'Pclass': 3, 'Sex': 'male'}
)

high_class_female = Condition(
    num_rows=10,
    column_values={'Pclass': 1, 'Sex': 'female'}
)

synthetic_data = synthesizer.sample_from_conditions(
    conditions=[low_class_male, high_class_female],
)
# Out:
# Sampling conditions: 100%|██████████| 20/20 [00:00<00:00, 72.27it/s]

# %%
synthetic_data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0       8778194         0       3
# 1       5096780         0       3
# 2       3131220         0       3
# 3      13773414         1       3
# 4      12259313         0       3
# 5      14807002         0       3
# 6       7576704         0       3
# 7       2068190         0       3
# 8       4891226         0       3
# 9       2444519         1       3
# 10     12690944         1       1
# 11     11341226         1       1
# 12      7680097         1       1
# 13      8883638         1       1
# 14      8042146         1       1
# 15      2819888         1       1
# 16      4073464         1       1
# 17       248514         1       1
# 18     10682724         1       1
# 19      3335921         1       1
#
#                                                  Name     Sex    Age  SibSp  \
# 0   Phillips, Miss. Kate Florence ("Mrs Kate Louis...    male  29.47      0
# 1            Humblen, Mr. Adolf Mathias Nicolai Olsen    male  28.56      0
# 2                                Williams, Mr. Leslie    male  28.09      0
# 3                     Bryhl, Mr. Kurt Arnold Gottfrid    male  16.30      0
# 4                                    Horgan, Mr. John    male  28.46      0
# 5                              Turkula, Mrs. (Hedwig)    male  23.05      0
# 6                          Lemberopolous, Mr. Peter L    male  28.20      0
# 7                                      Saad, Mr. Amin    male  17.25      0
# 8                            Cohen, Mr. Gurshon "Gus"    male  18.64      0
# 9                            Moubarek, Master. Gerios    male  20.86      0
# 10          Bjornstrom-Steffansson, Mr. Mauritz Hakan  female  29.58      1
# 11  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  34.91      1
# 12                                Ringhini, Mr. Sante  female  51.19      0
# 13                          Pears, Mr. Thomas Clinton  female  38.41      0
# 14                          Pears, Mr. Thomas Clinton  female  30.38      0
# 15                       Newsom, Miss. Helen Monypeny  female    NaN      0
# 16                            Bishop, Mr. Dickinson H  female  18.98      0
# 17      Quick, Mrs. Frederick Charles (Jane Richards)  female  29.28      0
# 18                  Pears, Mrs. Thomas (Edith Wearne)  female  45.83      0
# 19                     Thorne, Mrs. Gertrude Maybelle  female  36.42      0
#
#     Parch            Ticket      Fare Cabin Embarked
# 0       0            250655   20.8426   NaN        S
# 1       0            348121    9.5591   NaN        S
# 2       0              1601    9.0421   NaN        S
# 3       0              2661    8.7327   NaN        S
# 4       0            330877    9.0348   NaN        S
# 5       0            315097    9.3019   NaN        S
# 6       0              2683    7.9041   NaN        S
# 7       0          A/S 2816    9.2340   NaN        S
# 8       0  STON/O2. 3101279   10.8021   NaN        S
# 9       0  STON/O2. 3101279    7.6571   NaN        S
# 10      0            237736   52.2979   NaN        S
# 11      0             17421  149.8748   NaN        C
# 12      0          PC 17760   55.4397   NaN        S
# 13      0          PC 17760   45.8229   NaN        C
# 14      0             17421   78.5387   NaN        C
# 15      0             17421   59.3214   NaN        S
# 16      0          PC 17757   85.3699   NaN        C
# 17      0             17421   23.1405   NaN        S
# 18      0            113776   62.2563   NaN        S
# 19      0      S.O.C. 14879   66.9711   NaN        S

# %%
synthesizer = TVAESynthesizer(metadata, embedding_dim=256)
synthesizer.fit(titanic)

# %%
synthesizer.sample_from_conditions(
    conditions=[low_class_male, high_class_female],
)
# Out:
# Sampling conditions: 100%|██████████| 20/20 [00:00<00:00, 123.14it/s]
#     PassengerId  Survived  Pclass  \
# 0       7710494         0       3
# 1       7551801         0       3
# 2       4337276         0       3
# 3        952258         0       3
# 4      16251090         0       3
# 5        149377         0       3
# 6        378689         0       3
# 7       1221140         0       3
# 8       9563231         0       3
# 9      10802859         0       3
# 10     12483271         1       1
# 11     10542468         1       1
# 12      5060083         1       1
# 13     13279648         1       1
# 14       811273         1       1
# 15      6916437         1       1
# 16      4820819         1       1
# 17      8206052         1       1
# 18      5537852         1       1
# 19     12258924         1       1
#
#                                                  Name     Sex    Age  SibSp  \
# 0                         Parkes, Mr. Francis "Frank"    male  28.65      0
# 1                             Green, Mr. George Henry    male  21.58      0
# 2                                   Badt, Mr. Mohamed    male    NaN      0
# 3                     Nilsson, Miss. Helmina Josefina    male    NaN      0
# 4                                 Baumann, Mr. John D    male  28.15      0
# 5                                McGovern, Miss. Mary    male    NaN      0
# 6                   Lindblom, Miss. Augusta Charlotta    male  30.00      0
# 7                        Lemore, Mrs. (Amelia Milley)    male  27.35      0
# 8                              Lievens, Mr. Rene Aime    male  23.51      0
# 9                             Moen, Mr. Sigurd Hansen    male  30.94      0
# 10                        Compton, Miss. Sara Rebecca  female  48.67      1
# 11                              Natsch, Mr. Charles H  female    NaN      0
# 12                 Frolicher, Miss. Hedwig Margaritha  female  54.44      1
# 13             Laroche, Mr. Joseph Philippe Lemercier  female    NaN      0
# 14                              Natsch, Mr. Charles H  female  30.71      0
# 15                           Sage, Mr. Douglas Bullen  female  28.86      0
# 16                          Dodge, Master. Washington  female  20.69      1
# 17  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  43.03      1
# 18                        Williams, Mr. Charles Duane  female  35.47      0
# 19                      Cavendish, Mr. Tyrell William  female  38.90      0
#
#     Parch         Ticket      Fare Cabin Embarked
# 0       0         239853    4.6692   NaN        S
# 1       0          21440    9.0164   NaN        S
# 2       0           2620    9.5398   NaN        S
# 3       0         349244   10.4156   NaN        S
# 4       0           2699   22.1643   NaN        S
# 5       0         371110    9.4352   NaN        S
# 6       0          54636    5.7553   NaN        S
# 7       0    S.O./P.P. 3   10.7468   NaN        S
# 8       0         345781    9.3658   NaN        S
# 9       0           2623    8.5023   NaN        S
# 10      0         110413   73.2426   NaN        C
# 11      0   S.O.C. 14879   32.0660   NaN        S
# 12      0       PC 17760   63.0204   NaN        S
# 13      0  SC/Paris 2123   36.5667   NaN        S
# 14      0   S.O.C. 14879   38.7267   NaN        S
# 15      0       CA. 2343   79.6755   NaN        S
# 16      2         113781  192.7185   NaN        S
# 17      1       PC 17582  112.4698   D35        S
# 18      0       PC 17760   74.0185   NaN        S
# 19      0          19877   76.3049   NaN        C

# %%
from sdv.evaluation.single_table import get_column_plot

get_column_plot(
    real_data=titanic,
    synthetic_data=fake_titanic,
    metadata=metadata,
    column_name='Survived'
)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_25.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
from sdv.evaluation.single_table import get_column_pair_plot

get_column_pair_plot(
    real_data=titanic,
    synthetic_data=fake_titanic,
    metadata=metadata,
    column_names=['Survived', 'Sex'],
)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_27.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
